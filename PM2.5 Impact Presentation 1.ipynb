# %% [markdown]
# ## An Investigation of Particulate Matter 2.5 and Other Air Pollutants impact in DMV During the COVID-19 Pandemic

# %% [markdown]
# ## Data Sciecne Workflow
#
# ### Part I
#
# ![image-6.png](attachment:image-6.png)
#
#
# ####  Dimention Reduction :
#
#  Data Reduction improves the interpretation of the parameters of the machine learning model by removing irrelevant data.
#
# ##### Attribute Subset Selection Method
#
#   As mentioned in part I , Initially the dataset containing 879531 Columns and 29 Rows were Collected from Environmental
#   Protection Agency (EPA) was collected. Based on the data science process , stage 3, The large data set has many attributes
#   some of which are irrelevant to data mining or some are redundant. The attribute subset selection reduces the volume of data
#   by eliminating the redundant and irrelevant attribute.

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('DMV10042.csv',header= 0)

# %%
data.head() # Partial view of the data
# Out:
#     Ozone_ Contn   NO2_Contn   CO_ Concn  Temp_ Avg   SO2 _Contn  \
# 0          0.019        21.7         0.3          34        11.2
# 1          0.020        19.0         0.3          42         8.0
# 2          0.016        24.9         0.3          42         6.4
# 3          0.014        22.1         0.3          53        14.4
# 4          0.013        28.6         0.3          67        10.4
#
#     PM2.5_Contn  deathIncrease
# 0          11.5             14
# 1           4.8             11
# 2           6.7              8
# 3           7.2              3
# 4           8.2             14

# %%
data.shape
# Out:
# (129, 7)

# %%
data.head()
# Out:
#     Ozone_ Contn   NO2_Contn   CO_ Concn  Temp_ Avg   SO2 _Contn  \
# 0          0.019        21.7         0.3          34        11.2
# 1          0.020        19.0         0.3          42         8.0
# 2          0.016        24.9         0.3          42         6.4
# 3          0.014        22.1         0.3          53        14.4
# 4          0.013        28.6         0.3          67        10.4
#
#     PM2.5_Contn  deathIncrease
# 0          11.5             14
# 1           4.8             11
# 2           6.7              8
# 3           7.2              3
# 4           8.2             14

# %%
 data.head()
# Out:
#     Ozone_ Contn   NO2_Contn   CO_ Concn  Temp_ Avg   SO2 _Contn  \
# 0          0.019        21.7         0.3          34        11.2
# 1          0.020        19.0         0.3          42         8.0
# 2          0.016        24.9         0.3          42         6.4
# 3          0.014        22.1         0.3          53        14.4
# 4          0.013        28.6         0.3          67        10.4
#
#     PM2.5_Contn  deathIncrease
# 0          11.5             14
# 1           4.8             11
# 2           6.7              8
# 3           7.2              3
# 4           8.2             14

# %%
data.columns   # Unifying the datattypes - to integer
# Out:
# Index([' Ozone_ Contn', ' NO2_Contn', ' CO_ Concn', 'Temp_ Avg ', 'SO2 _Contn',
#        ' PM2.5_Contn', 'deathIncrease'],
#       dtype='object')

# %%
x_data = data[[' Ozone_ Contn', ' NO2_Contn', ' CO_ Concn', 'Temp_ Avg ', 'SO2 _Contn',
       ' PM2.5_Contn', 'deathIncrease']].astype(int)
x_data.head()
# Out:
#     Ozone_ Contn   NO2_Contn   CO_ Concn  Temp_ Avg   SO2 _Contn  \
# 0              0          21           0          34          11
# 1              0          19           0          42           8
# 2              0          24           0          42           6
# 3              0          22           0          53          14
# 4              0          28           0          67          10
#
#     PM2.5_Contn  deathIncrease
# 0            11             14
# 1             4             11
# 2             6              8
# 3             7              3
# 4             8             14

# %%
x_data.plot.area()                               # Partial View of all the  Concentrationd/month 

plt.xlabel("Monthly Period ")
plt.ylabel("Ozone,NO2,CO,SO2,Temp_ Avg,and PM2.5,CvdDz")
plt.title ("Concentrations of Gaseous Elements and Covid_Death")
plt.plot(x)
plt.plot(y)

# %%
data[' PM2.5_Contn']=data[' PM2.5_Contn'].astype(int)

# %%
x_data.head()
# Out:
#     Ozone_ Contn   NO2_Contn   CO_ Concn  Temp_ Avg   SO2 _Contn  \
# 0              0          21           0          34          11
# 1              0          19           0          42           8
# 2              0          24           0          42           6
# 3              0          22           0          53          14
# 4              0          28           0          67          10
#
#     PM2.5_Contn  deathIncrease
# 0            11             14
# 1             4             11
# 2             6              8
# 3             7              3
# 4             8             14

# %%
alldata = x_data.describe()
alldata
# Out:
#         Ozone_ Contn   NO2_Contn   CO_ Concn  Temp_ Avg   SO2 _Contn  \
# count          129.0  129.000000  129.000000  129.000000  129.000000
# mean             0.0   27.248062    0.015504   54.891473   11.922481
# std              0.0   12.595281    0.124027   15.662076    6.705423
# min              0.0    4.000000    0.000000   18.000000    4.000000
# 25%              0.0   18.000000    0.000000   41.000000    8.000000
# 50%              0.0   27.000000    0.000000   53.000000   10.000000
# 75%              0.0   37.000000    0.000000   68.000000   13.000000
# max              0.0   61.000000    1.000000   83.000000   39.000000
#
#         PM2.5_Contn  deathIncrease
# count    129.000000     129.000000
# mean       7.155039      29.674419
# std        3.516589      15.167895
# min        2.000000       3.000000
# 25%        5.000000      18.000000
# 50%        6.000000      29.000000
# 75%        9.000000      41.000000
# max       17.000000      66.000000

# %%
y_data = data[[' PM2.5_Contn', 'deathIncrease']]     # partial view of PM2.5 and Covid death.
y_data
# Out:
#       PM2.5_Contn  deathIncrease
# 0              11             14
# 1               4             11
# 2               6              8
# 3               7              3
# 4               8             14
# ..            ...            ...
# 124             4              7
# 125             4              3
# 126             4              5
# 127             3             10
# 128             6             10
#
# [129 rows x 2 columns]

# %%
y_data.plot.area()
plt.xlabel("Monthly Period ")
plt.ylabel("Concentration of PM2.5 and Increasing death due to Covid")
plt.title("Concentrations ofPM2.5 vs Deaceased due to Covid")
plt.plot(x)
plt.plot(y)

# %%
plt1= data[['deathIncrease']]   # Partial View of Covid Deaths

# %%
plt1.head(3)
# Out:
#    deathIncrease
# 0             14
# 1             11
# 2              8

# %%
x_data.head()
# Out:
#     Ozone_ Contn   NO2_Contn   CO_ Concn  Temp_ Avg   SO2 _Contn  \
# 0              0          21           0          34          11
# 1              0          19           0          42           8
# 2              0          24           0          42           6
# 3              0          22           0          53          14
# 4              0          28           0          67          10
#
#     PM2.5_Contn  deathIncrease
# 0            11             14
# 1             4             11
# 2             6              8
# 3             7              3
# 4             8             14

# %%
plt2 =x_data[[' PM2.5_Contn']]  # Partial View of PM2.5 Concentrations

# %%
plt2.plot.area()
plt.xlabel("Monthly Period ")
plt.ylabel("Concentration of PM2.5")
plt.title("Monthly Concentrations of PM 2.5 ")
plt.plot(x)
plt.plot(y)

# %%
x=plt1
y=plt2

# %%
plt.xlabel("PM2.5")
plt.ylabel("Covid Death")
plt.title(" PM2.5 and Covid Desceased")
plt.plot(x,)
plt.plot(y,)

# %%
x_data.head()    # Partial View of  the datastes
# Out:
#     Ozone_ Contn   NO2_Contn   CO_ Concn  Temp_ Avg   SO2 _Contn  \
# 0              0          21           0          34          11
# 1              0          19           0          42           8
# 2              0          24           0          42           6
# 3              0          22           0          53          14
# 4              0          28           0          67          10
#
#     PM2.5_Contn  deathIncrease
# 0            11             14
# 1             4             11
# 2             6              8
# 3             7              3
# 4             8             14

# %%
x_data.columns
# Out:
# Index([' Ozone_ Contn', ' NO2_Contn', ' CO_ Concn', 'Temp_ Avg ', 'SO2 _Contn',
#        ' PM2.5_Contn', 'deathIncrease'],
#       dtype='object')

# %%
N2S2 = x_data[[' NO2_Contn', 'SO2 _Contn']]
N2S2.head(3)                                          # Partial View of Nitrogen and Sulpher Concentrations
# Out:
#     NO2_Contn  SO2 _Contn
# 0          21          11
# 1          19           8
# 2          24           6

# %%
N2S2.plot.line()
plt.xlabel("Monthly Period ")
plt.ylabel("Concentration of NO2")
plt.title("Concentrations of NO2 Gaseous Elements")
plt.plot(x)
plt.plot(y)

# %%
z=N2S2         
z.head(3) # Concentration of N02 and S02
# Out:
#     NO2_Contn  SO2 _Contn
# 0          21          11
# 1          19           8
# 2          24           6

# %%
z=N2S2    # Concentration of N02 and S02 vs Covid Death
plt.xlabel("Nitrogen Oxide and Sulphur Oxide Constn")
plt.ylabel("Covid Death")
plt.title(" Nitrogen Oxide and Sulphur Oxide Constn and PM2.5 and  Covid Desceased")
plt.plot(z)
plt.plot(y)

# %%
OZCO=x_data[[' Ozone_ Contn',' CO_ Concn']]
OZCO.head (3)                                      # Partial View of Ozone and Carbon Monoxide Concentrations
# Out:
#     Ozone_ Contn   CO_ Concn
# 0              0           0
# 1              0           0
# 2              0           0

# %%
w=OZCO
w.head(3)
# Out:
#     Ozone_ Contn   CO_ Concn
# 0              0           0
# 1              0           0
# 2              0           0

# %%
w=OZCO                         # Partial View of all  Ozone and Carbon Mono Oxide Concentrationd/month
plt.xlabel("Ozone and Carbon Mono Oxide Constn")
plt.ylabel("Covid Death")
plt.title(" Ozone and Carbon Mono Oxide Constn vs PM2.5 and  Covid Desceased")
plt.plot(w)
plt.plot(y)

# %%
x_data.head()
# Out:
#     Ozone_ Contn   NO2_Contn   CO_ Concn  Temp_ Avg   SO2 _Contn  \
# 0              0          21           0          34          11
# 1              0          19           0          42           8
# 2              0          24           0          42           6
# 3              0          22           0          53          14
# 4              0          28           0          67          10
#
#     PM2.5_Contn  deathIncrease
# 0            11             14
# 1             4             11
# 2             6              8
# 3             7              3
# 4             8             14

# %%
 x_data.columns
# Out:
# Index([' Ozone_ Contn', ' NO2_Contn', ' CO_ Concn', 'Temp_ Avg ', 'SO2 _Contn',
#        ' PM2.5_Contn', 'deathIncrease'],
#       dtype='object')

# %%
Temp =x_data[['Temp_ Avg ', ' PM2.5_Contn', 'deathIncrease']] 
Temp.head(3)                                                           # Partial View of temp , PM2.5  concn and Covid death
# Out:
#    Temp_ Avg    PM2.5_Contn  deathIncrease
# 0          34            11             14
# 1          42             4             11
# 2          42             6              8

# %%
Temp.plot() # Temperature, PM2.5 and Covid Death relation 

plt.xlabel("Monthly Rate")
plt.ylabel(['Temp_ Avg ', ' PM2.5_Contn', 'deathIncrease'])
plt.title(" Temperature, PM2.5 and Covid Death relation ")
# Out:
# Text(0.5, 1.0, ' Temperature, PM2.5 and Covid Death relation ')

# %%
alldata = x_data.describe()                # This is a statistical details of the sample datatsets and different outputs
                                           # to show what the data looks like 
alldata
# Out:
#         Ozone_ Contn   NO2_Contn   CO_ Concn  Temp_ Avg   SO2 _Contn  \
# count          129.0  129.000000  129.000000  129.000000  129.000000
# mean             0.0   27.248062    0.015504   54.891473   11.922481
# std              0.0   12.595281    0.124027   15.662076    6.705423
# min              0.0    4.000000    0.000000   18.000000    4.000000
# 25%              0.0   18.000000    0.000000   41.000000    8.000000
# 50%              0.0   27.000000    0.000000   53.000000   10.000000
# 75%              0.0   37.000000    0.000000   68.000000   13.000000
# max              0.0   61.000000    1.000000   83.000000   39.000000
#
#         PM2.5_Contn  deathIncrease
# count    129.000000     129.000000
# mean       7.155039      29.674419
# std        3.516589      15.167895
# min        2.000000       3.000000
# 25%        5.000000      18.000000
# 50%        6.000000      29.000000
# 75%        9.000000      41.000000
# max       17.000000      66.000000

# %%
corr=alldata.corr()
corr
# Out:
#                 Ozone_ Contn   NO2_Contn   CO_ Concn  Temp_ Avg   SO2 _Contn  \
#  Ozone_ Contn       1.000000    0.903017    0.999971    0.781468    0.966331
#  NO2_Contn          0.903017    1.000000    0.905541    0.958572    0.975920
#  CO_ Concn          0.999971    0.905541    1.000000    0.784129    0.968150
# Temp_ Avg           0.781468    0.958572    0.784129    1.000000    0.883151
# SO2 _Contn          0.966331    0.975920    0.968150    0.883151    1.000000
#  PM2.5_Contn        0.994429    0.942703    0.995085    0.836487    0.987376
# deathIncrease       0.882178    0.998653    0.884925    0.964340    0.964859
#
#                 PM2.5_Contn  deathIncrease
#  Ozone_ Contn      0.994429       0.882178
#  NO2_Contn         0.942703       0.998653
#  CO_ Concn         0.995085       0.884925
# Temp_ Avg          0.836487       0.964340
# SO2 _Contn         0.987376       0.964859
#  PM2.5_Contn       1.000000       0.926069
# deathIncrease      0.926069       1.000000

# %%
alldata =sns.heatmap(corr,annot=True,cmap="RdYlGn")  # The heat map depicting the relationship of the gaseous elements. 
                                                     # From the graph, we can see that as one read from bottom to top - bold green , shows strong correlation
                                                     # N02 and CO have srtong correlation with PM2.5 and Covid death.

# %%
m = x_data[[' NO2_Contn']]

# %%
n= x_data[[ ' PM2.5_Contn']]

# %% [markdown]
#    ## Next Step
#    ![image-2.png](attachment:image-2.png)
